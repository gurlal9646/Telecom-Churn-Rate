# %%
import pandas as pd
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPRegressor
from sklearn import datasets
from sklearn.preprocessing import scale
# Out:
# /Users/ashok/anaconda3/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /Users/ashok/anaconda3/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %%
data = pd.read_csv("telecom_churn_data.csv")
data.columns = ['state','A/c_len','area_code','phone','int_plan','Vmail_plan','Vmail_msg','Day_mins','Day_calls','Day_charge','Eve_mins','Eve_calls','Eve_charge','Nig_mins','Nig_calls','Nig_charge','int_mins','int_calls','int_charge','Custserv_calls','churn']
data.head()
# Out:
#   state  A/c_len  area_code      phone int_plan Vmail_plan  Vmail_msg  \
# 0    OH      107        415   371-7191       no        yes         26
# 1    NJ      137        415   358-1921       no         no          0
# 2    OH       84        408   375-9999      yes         no          0
# 3    OK       75        415   330-6626      yes         no          0
# 4    AL      118        510   391-8027      yes         no          0
#
#    Day_mins  Day_calls  Day_charge   ...     Eve_calls  Eve_charge  Nig_mins  \
# 0     161.6        123       27.47   ...           103       16.62     254.4
# 1     243.4        114       41.38   ...           110       10.30     162.6
# 2     299.4         71       50.90   ...            88        5.26     196.9
# 3     166.7        113       28.34   ...           122       12.61     186.9
# 4     223.4         98       37.98   ...           101       18.75     203.9
#
#    Nig_calls  Nig_charge  int_mins  int_calls  int_charge  Custserv_calls  \
# ...

# %%
from collections import Counter
Counter(data.Vmail_plan)
# Out:
# Counter({' no': 3381, ' yes': 1235})

# %%
from sklearn.preprocessing import LabelEncoder
enc = LabelEncoder()

# %%
data.int_plan = enc.fit_transform(data.int_plan)
data.Vmail_plan = enc.fit_transform(data.Vmail_plan)
data.churn = enc.fit_transform(data.churn)

# %%
data.corr()
# Out:
#                  A/c_len  area_code  int_plan  Vmail_plan  Vmail_msg  \
# A/c_len         1.000000  -0.020318  0.013998   -0.004852  -0.013175
# area_code      -0.020318   1.000000  0.039227   -0.002964  -0.002455
# int_plan        0.013998   0.039227  1.000000    0.009398   0.011687
# Vmail_plan     -0.004852  -0.002964  0.009398    1.000000   0.955276
# Vmail_msg      -0.013175  -0.002455  0.011687    0.955276   1.000000
# Day_mins        0.001768  -0.018729  0.028339    0.003884   0.008603
# Day_calls       0.032711  -0.013123  0.007513   -0.005919  -0.003983
# Day_charge      0.001765  -0.018731  0.028342    0.003882   0.008600
# Eve_mins       -0.006770   0.011507  0.023736    0.021803   0.017891
# Eve_calls       0.015608  -0.011535  0.003356   -0.005514  -0.006493
# Eve_charge     -0.006766   0.011527  0.023736    0.021807   0.017898
# Nig_mins       -0.002208   0.002893 -0.025891    0.006121   0.004435
# Nig_calls      -0.009415   0.015267  0.007359    0.008632   0.001012
# ...

# %%
data.isnull().sum()
# Out:
# state             0
# A/c_len           0
# area_code         0
# phone             0
# int_plan          0
# Vmail_plan        0
# Vmail_msg         0
# Day_mins          0
# Day_calls         0
# Day_charge        0
# Eve_mins          0
# Eve_calls         0
# Eve_charge        0
# Nig_mins          0
# Nig_calls         0
# Nig_charge        0
# int_mins          0
# int_calls         0
# int_charge        0
# Custserv_calls    0
# churn             0
# dtype: int64

# %%
from collections import Counter
Counter(data.churn)
# Out:
# Counter({0: 3960, 1: 656})

# %%
# data.Day_mins  =data.Day_mins .astype('int')
# data.Day_charge =data.Day_charge.astype('int')
# data.Eve_mins =data.Eve_mins.astype('int')
# data.Eve_charge =data.Eve_charge.astype('int')
# data.Nig_mins =data.Nig_mins.astype('int')
# data.Nig_charge =data.Nig_charge.astype('int')
# data.int_mins  =data.int_mins .astype('int')
# data.int_charge =data.int_charge.astype('int')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4616 entries, 0 to 4615
# Data columns (total 21 columns):
# state             4616 non-null object
# A/c_len           4616 non-null int64
# area_code         4616 non-null int64
# phone             4616 non-null object
# int_plan          4616 non-null int64
# Vmail_plan        4616 non-null int64
# Vmail_msg         4616 non-null int64
# Day_mins          4616 non-null float64
# Day_calls         4616 non-null int64
# Day_charge        4616 non-null float64
# Eve_mins          4616 non-null float64
# Eve_calls         4616 non-null int64
# Eve_charge        4616 non-null float64
# Nig_mins          4616 non-null float64
# Nig_calls         4616 non-null int64
# Nig_charge        4616 non-null float64
# int_mins          4616 non-null float64
# int_calls         4616 non-null int64
# int_charge        4616 non-null float64
# Custserv_calls    4616 non-null int64
# churn             4616 non-null int64
# ...

# %%
x = data.iloc[:,1:]
y = data.churn
X =x.drop(columns=['phone'])
#from sklearn.preprocessing import scale
#x = scale(x)

# %%
X_train, X_test,y_train,y_test = train_test_split(X,y, random_state=10)

# %%
X_train.shape
# Out:
# (3462, 19)

# %%
X_test.shape
# Out:
# (1154, 19)

# %%
from sklearn.neural_network import MLPClassifier
model = MLPClassifier(max_iter=100000,hidden_layer_sizes=(100),learning_rate_init=0.001)
model.fit (X_train,y_train)
# Out:
# MLPClassifier(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=100, learning_rate='constant',
#        learning_rate_init=0.001, max_iter=100000, momentum=0.9,
#        nesterovs_momentum=True, power_t=0.5, random_state=None,
#        shuffle=True, solver='adam', tol=0.0001, validation_fraction=0.1,
#        verbose=False, warm_start=False)

# %%
from sklearn.metrics import accuracy_score
y_predict = model.predict(X_test)
accuracy_score(y_test, y_predict)
# Out:
# 0.9956672443674177

# %%
pd.crosstab(y_test, y_predict)
# Out:
# col_0    0    1
# churn
# 0      997    0
# 1        5  152

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
model.fit(X_train,y_train)
y_predict = model.predict(X_test)
pd.crosstab(y_test, y_predict)
# Out:
# /Users/ashok/anaconda3/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# col_0    0    1
# churn
# 0      997    0
# 1        0  157

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_predict)
# Out:
# 1.0

# %%
from sklearn.externals import joblib
joblib.dump(model,"no-churn-trained-model.ml")
# Out:
# ['no-churn-trained-model.ml']
